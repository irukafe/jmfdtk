# %%
from kokoro import kokoro

kokoro()
# Out:
# Document number: 110
# ### Loaded JMFD words
# AuthorityVice ==> stem:43 word:9
# AuthorityVirtue ==> stem:96 word:34
# FairnessVice ==> stem:31 word:3
# FairnessVirtue ==> stem:37 word:6
# HarmVice ==> stem:71 word:22
# HarmVirtue ==> stem:43 word:8
# IngroupVice ==> stem:30 word:12
# IngroupVirtue ==> stem:84 word:15
# PurityVice ==> stem:65 word:23
# PurityVirtue ==> stem:83 word:7
#
# Loading J-MFD completed.
# Segmentation completed.
# Counting completed.
# ### Document frequency: AuthorityVice
#    word  count    percent
# 0    反対     11  10.000000
# 1    忠告      6   5.454545
# 2    反抗      4   3.636364
# 3    失礼      3   2.727273
# 4    妨害      2   1.818182
# 5    拒絶      2   1.818182
# 6    侮辱      1   0.909091
# 7    倒す      1   0.909091
# 8    抵抗      1   0.909091
# 9    異議      1   0.909091
# 10   背く      1   0.909091
# ### Document frequency: AuthorityVirtue
#     word  count    percent
# 0    認める     20  18.181818
# 1     信用      9   8.181818
# ...
